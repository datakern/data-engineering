# %% [markdown]
# # Part C: Validate the processed data
#
# **Instructor Note:**
# Students should verify that their script actually worked by checking row counts and data types of the output files.

# %%
import pandas as pd

# %% [markdown]
# ## 1. Validate Orders

# %%
orders_clean = pd.read_csv('../data/processed/processed_orders.csv')
orders_clean.info()

# %% [markdown]
# **Validation Check:**
# - Did the date columns convert properly?
# *Wait!* `read_csv` will load dates as strings again unless we specify `parse_dates`. Students should realize this or notice it!

# %%
orders_clean = pd.read_csv('../data/processed/processed_orders.csv', parse_dates=['order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date'])
orders_clean.info()

# %% [markdown]
# ## 2. Validate Products

# %%
products_clean = pd.read_csv('../data/processed/processed_products.csv')
products_clean.isna().sum()

# %% [markdown]
# **Validation Check:**
# - `product_category_name` should have 0 missing values now, confirming our script worked.
