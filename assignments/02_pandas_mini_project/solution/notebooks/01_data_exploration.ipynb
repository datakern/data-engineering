# %% [markdown]
# # Part A: Explore and understand the data
#
# **Instructor Note:**
# Students should load each file, check shape, info, and missing values. They should document their findings in `docs/observations.md`.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Orders Dataset

# %%
orders = pd.read_csv('../data/raw/olist_orders_dataset.csv')
orders.head()

# %%
orders.shape

# %%
orders.info()

# %% [markdown]
# **Observation:** Dates are strings. Need to convert to datetime.

# %%
orders.isna().sum()

# %% [markdown]
# **Observation:** Missing values in delivery dates. This makes sense for cancelled or in-progress orders. Do not drop.

# %% [markdown]
# ## 2. Products Dataset

# %%
products = pd.read_csv('../data/raw/olist_products_dataset.csv')
products.info()

# %%
products.isna().sum()

# %% [markdown]
# **Observation:** Missing `product_category_name`. We can fill this with 'Unknown' instead of dropping, to preserve the product records.
